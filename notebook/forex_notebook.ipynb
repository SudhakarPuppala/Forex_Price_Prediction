# %% [markdown]
# <a href="https://colab.research.google.com/github/SUDHAKARPVV/Forex_Price_Prediction/blob/main/notebook/forex_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Replace 'Your Name' and 'your_email@example.com' with your actual Git credentials
# !git config --global user.email "sudhakar.pvv@gmail.com"
# !git config --global user.name "SUDHAKARPVV"

print("Git user configured.")
# Out:
# Git user configured.

# %%
# !git clone https://github.com/SUDHAKARPVV/Forex_Price_Prediction
# Out:
# Cloning into 'Forex_Price_Prediction'...
# remote: Enumerating objects: 2441, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 2441 (delta 139), reused 166 (delta 115), pack-reused 2220 (from 3)
# Receiving objects: 100% (2441/2441), 434.40 MiB | 18.99 MiB/s, done.
# Resolving deltas: 100% (895/895), done.
# Updating files: 100% (173/173), done.

# %%
import os
if os.getcwd() != '/content/Forex_Price_Prediction':
  # %cd /content/Forex_Price_Prediction
# !git pull
# Out:
# /content/Forex_Price_Prediction
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 9 (delta 7), reused 9 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 191.63 KiB | 109.00 KiB/s, done.
# From https://github.com/SUDHAKARPVV/Forex_Price_Prediction
#    b5fd384..b7607ca  main       -> origin/main
# Updating b5fd384..b7607ca
# Fast-forward
#  exports/archive/news_GCF.csv                       | 20778 ++++++++++---------
#  exports/pairs/XAUUSD/feature_panel.csv             |   534 +-
#  exports/pairs/XAUUSD/news_headlines_scored.csv     | 20182 +++++++++---------
#  .../pairs/XAUUSD/sentiment_features_per_bar.csv    |   534 +-
#  4 files changed, 21434 insertions(+), 20594 deletions(-)

# %%
cd /content/Forex_Price_Prediction
# Out:
# /content/Forex_Price_Prediction

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 92.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 100.4 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=6dbd23379cb512370a08748505df724e09362fc9ac9db713eba7187f8dbe837c
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# ...

# %%
# !pip install arch

# %%
# !python ./tests/test_pipeline.py
# Out:
# [PASS] synthetic data shapes
# [PASS] technical indicators
# ...
# config.json: 100% 758/758 [00:00<00:00, 2.03MB/s]
#
# pytorch_model.bin: downloading bytes:  92% 404M/438M [00:02<00:00, 107MB/s, 33.6MB/s  ]
# pytorch_model.bin: reconstructing file:  61% 268M/438M [00:03<00:02, 83.8MB/s]
# pytorch_model.bin: downloading bytes: 100% 413M/413M [00:05<00:00, 74.8MB/s, 34.7MB/s  ]
# pytorch_model.bin: reconstructing file: 100% 438M/438M [00:05<00:00, 79.3MB/s, 35.1MB/s  ]
#
# model.safetensors: downloading bytes:   0% 0.00/438M [00:00<?, ?B/s]
#
# Loading weights: 100% 201/201 [00:00<00:00, 22275.35it/s]
#
#
# tokenizer_config.json: 100% 252/252 [00:00<00:00, 678kB/s]
#
#
# vocab.txt: 100% 232k/232k [00:00<00:00, 14.1MB/s]
# model.safetensors: downloading bytes:   6% 26.2M/438M [00:00<00:06, 65.4MB/s,   ???B/s  ]
#
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 132kB/s]
# ...

# %%
# !python ./scripts/train_pairs.py --pairs XAU/USD --interval 1h  --epoch 30
# Out:
# ===== XAU/USD (Gold (XAU/USD)) @ 1h =====
# [train_pairs] train stride 3: train 43,374->14,458, val 9,306->3,102 (test untouched)
# [train_pairs] XAUUSD: 62049 bars, train=14458 val=3102 test=9297
# [garch-expert] loaded 26857 walk-forward GARCH forecasts (hash OK)
# [wf-expert] block 1/93: refit on 17557 windows (cutoff idx 52730), predicted 100
# [wf-expert] block 2/93: refit on 17650 windows (cutoff idx 52830), predicted 100
# [wf-expert] block 3/93: refit on 17750 windows (cutoff idx 52930), predicted 100
# [wf-expert] block 4/93: refit on 17850 windows (cutoff idx 53030), predicted 100
# [wf-expert] block 5/93: refit on 17950 windows (cutoff idx 53130), predicted 100
# [wf-expert] block 6/93: refit on 18050 windows (cutoff idx 53230), predicted 100
# [wf-expert] block 7/93: refit on 18150 windows (cutoff idx 53330), predicted 100
# [wf-expert] block 8/93: refit on 18250 windows (cutoff idx 53430), predicted 100
# ...

# %%
import os
os.environ["FOREX_WF_EXPERT"] = "0"          # skip the 665-block walk-forward expert
# !python ./scripts/run_multi_seed.py --seeds 9 36 99 --pair XAU/USD --interval 1h
# Out:
# [gate] feature panel OK: 62049 bars, test-set sentiment coverage 99.9%
#
# ...
# SEED 9
# ...
#
# === Building multi-modal panel for XAU/USD (source=panel, n_days=100, interval=1h) ===
# [data] panel source actually used: real  (signal_strength=n/a)
# train=43374  val=9306  test=9297  features=37
# [stationarity] ADF statistic=-1.0742  p-value=0.9333  -> non-stationary (unit root present, as Paper 1 also found)
#
# === Fitting XGBoost expert (fused inside the Hybrid architecture) ===
# [features] XGBoost importance audit -- top: bb_pctb=0.037, sent_std=0.036, sig_hold=0.034, atr_pct=0.034, sig_none=0.034, ema_ratio=0.034
# [features] lowest-importance (noise candidates): sig_sell=0.020, ret_open=0.020, cpi_mom=0.000, cpi_yoy=0.000, days_since_cpi=0.000
# [garch-expert] loaded 26857 walk-forward GARCH forecasts (hash OK)
#
# === Training Hybrid CNN-LSTM-Transformer (+ internally-fused XGBoost branch) ===
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

report_path = '/content/Forex_Price_Prediction/results/evaluation_report.json'

with open(report_path, 'r') as f:
    evaluation_report = json.load(f)

# Display the entire report for detailed summary
display(evaluation_report)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1187/2124888143.py in <cell line: 0>()
#       3 report_path = '/content/Forex_Price_Prediction/results/evaluation_report.json'
#       4
# ----> 5 with open(report_path, 'r') as f:
#       6     evaluation_report = json.load(f)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Forex_Price_Prediction/results/evaluation_report.json'

# %%
summary_metrics = []

for pair, models_data in evaluation_report.get('pair_metrics', {}).items():
    for model_name, metrics in models_data.items():
        row = {
            'Pair': pair,
            'Model': model_name,
            'RMSE': metrics.get('test_rmse', 'N/A'),
            'MAE': metrics.get('test_mae', 'N/A'),
            'R2 Score': metrics.get('test_r2', 'N/A'),
            'Sharpe Ratio': metrics.get('sharpe_ratio', 'N/A'),
            'Max Drawdown': metrics.get('max_drawdown', 'N/A'),
            'Total Return': metrics.get('total_return', 'N/A'),
            'Win Rate': metrics.get('win_rate', 'N/A')
        }
        summary_metrics.append(row)

summary_df = pd.DataFrame(summary_metrics)
display(summary_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1187/1597484309.py in <cell line: 0>()
#       1 summary_metrics = []
#       2
# ----> 3 for pair, models_data in evaluation_report.get('pair_metrics', {}).items():
#       4     for model_name, metrics in models_data.items():
#       5         row = {
#
# NameError: name 'evaluation_report' is not defined

# %% [markdown]
# This table provides a concise overview of each model's performance on various metrics including prediction accuracy (RMSE, MAE, R2) and trading performance (Sharpe Ratio, Max Drawdown, Total Return, Win Rate).

# %% [markdown]
# ### Configure Git User
# First, you need to configure your Git username and email address if you haven't already done so. This information will be associated with your commits.

# %% [markdown]
# ### Stage, Commit, and Push Changes
# Now you can stage all changes (add them to the Git index), commit them with a message, and push them to your remote GitHub repository.

# %%
# Add all changed files to the staging area
# !git add .

# Commit the staged changes
commit_message = "Commit results and modified files from Colab"
# !git commit -m "{commit_message}"

# Push the changes to the 'main' branch (or your default branch)
# !git push origin main

print("Changes committed and pushed to GitHub.")
# Out:
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> Forex_Price_Prediction
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached Forex_Price_Prediction
# hint:
# hint: See "git help submodule" for more information.
# [main f59f4ec] Commit results and modified files from Colab
#  3 files changed, 48 insertions(+), 21 deletions(-)
#  create mode 160000 Forex_Price_Prediction
# fatal: could not read Username for 'https://github.com': No such device or address
# Changes committed and pushed to GitHub.

# %%
import os

# Ensure we are in the correct directory
if os.getcwd() != '/content/Forex_Price_Prediction':
  # %cd /content/Forex_Price_Prediction

# Revert all changes in the current directory to the last committed state
# !git restore .

print("All local changes have been reverted.")
# Out:
# All local changes have been reverted.

# %%
# !python dashboard/app.py
# Out:
# 2026-07-18 12:29:29.576 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-18 12:29:29.579 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-18 12:29:29.623
# ...
#   command:
#
#     streamlit run dashboard/app.py [ARGUMENTS]
# 2026-07-18 12:29:29.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-18 12:29:29.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-18 12:29:29.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-18 12:29:29.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
